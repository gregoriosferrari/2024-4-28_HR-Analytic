# %% [markdown]
# **Translating Raw Data**
# - Preprocess ulasan
# - Translate with Gemini API
# - Save translated dataframe

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import json

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Import Dataset
# *   Raw dataset: 2024-3-25_cleanedUlasan.csv

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/2024-3-25_cleanedUlasan.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0                                Location  \
# 0           1  Manna+Kampus+(Mirota+Kampus)+Babarsari
# 1           2  Manna+Kampus+(Mirota+Kampus)+Babarsari
#
#                    AccountName  ReviewCount  \
# 0  Reni NuryyatiLocal Guide ·         382.0
# 1                 Bagus Nandar          2.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                               ulasan
# 0                                                                          Saat ramadhan dan mendekati lebaran seperti ini, seharusnya pelayanan lebih cepat.\rKassa satunya tutup. Pengunjung lainnya sampai pada jongkok krn sangat lama.\rSaya mengantri lbh dr 20 menit.\rMohon perbaiki lg pelayanannya. Di cabang yg lain tidak selama ini. Ini lama bukan krn belanjaan pengunjung banyak. Tp proses input ke mesin yang lama.\rTerima kasih.
# 1  Sudah langganan berbelanja di sini dari dulu, tapi barusan kecewa sama pelayanan karyawati inisial ES, karena kasir bagian roti tutup, istri saya diharuskan ngantri lagi ke kasir swalayan,..\rpoin di sini adalah di saat pelanggan komplain..petugas malah sewot, nggak ada senyum, nggak ada ramah, nggak ada maaf, harus dididik lagi supaya bisa menanggapin komplain dengan baik, bukan dengan cara argumen dengan nada yang tinggi/marah²

# %%
# Drop unused column
df = df.drop(df.columns[0], axis=1)
df.info()

# Create translate column
df['translate'] = None
# Remove Null in 'ulasan'
df.dropna(subset=['ulasan'], inplace=True)
# Remove row only containing space in 'ulasan'
df = df[df['ulasan'].str.strip() != '']
df = df.copy()
# Remove new line character from 'ulasan'
df['ulasan'] = df['ulasan'].str.replace('\r', ' ')
df['ulasan'] = df['ulasan'].str.replace('\n', ' ')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4760 entries, 0 to 4759
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location     4760 non-null   object
#  1   AccountName  4746 non-null   object
#  2   ReviewCount  4752 non-null   float64
#  3   ulasan       2852 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 148.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2849 entries, 0 to 4750
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location     2849 non-null   object
#  1   AccountName  2842 non-null   object
#  2   ReviewCount  2849 non-null   float64
#  3   ulasan       2849 non-null   object
#  4   translate    0 non-null      object
# dtypes: float64(1), object(4)
# memory usage: 133.5+ KB

# %% [markdown]
# # Cleaning text data

# %%
# Remove emoji and unknown character from 'ulasan'
import re

def clean_text(text):
  if isinstance(text, str):
    # Remove special characters and punctuation
    text = re.sub(r"[^\w\s]", " ", text)

    # Remove single characters
    text = re.sub(r"\b[a-zA-Z]\b", " ", text)

    # Remove HTML tags
    text = re.sub(r"<[^>]*>", " ", text)

    # Lowercase the text
    text = text.lower()

    # Remove extra whitespace
    text = re.sub(r"\s+", " ", text)

    # Trim leading and trailing spaces
    text = text.strip()

    # Pattern to match emojis
    emoji_pattern = re.compile("["
                                u"\U0001F600-\U0001F64F"  # emoticons
                                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                                u"\U0001F680-\U0001F6FF"  # transport & map symbols
                                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                                "]+", flags=re.UNICODE)

    text = emoji_pattern.sub(r'', text)

    return text
  else:
    return text

# %%
# Apply clean_text function to 'ulasan'
df['ulasan'] = df['ulasan'].apply(clean_text)

# %%
# Change "+" to space in 'Location'
df['Location'] = df['Location'].str.replace('+', ' ')

# %%
# Add row_number
df['Row_Num'] = df.index

# %%
df.head(2)
# Out:
#                                  Location                  AccountName  \
# 0  Manna Kampus (Mirota Kampus) Babarsari  Reni NuryyatiLocal Guide ·
# 1  Manna Kampus (Mirota Kampus) Babarsari                 Bagus Nandar
#
#    ReviewCount  \
# 0        382.0
# 1          2.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                  ulasan  \
# 0                                                                           saat ramadhan dan mendekati lebaran seperti ini seharusnya pelayanan lebih cepat kassa satunya tutup pengunjung lainnya sampai pada jongkok krn sangat lama saya mengantri lbh dr 20 menit mohon perbaiki lg pelayanannya di cabang yg lain tidak selama ini ini lama bukan krn belanjaan pengunjung banyak tp proses input ke mesin yang lama terima kasih
# 1  sudah langganan berbelanja di sini dari dulu tapi barusan kecewa sama pelayanan karyawati inisial es karena kasir bagian roti tutup istri saya diharuskan ngantri lagi ke kasir swalayan poin di sini adalah di saat pelanggan komplain petugas malah sewot nggak ada senyum nggak ada ramah nggak ada maaf harus dididik lagi supaya bisa menanggapin komplain dengan baik bukan dengan cara argumen dengan nada yang tinggi marah²
#
#   translate  Row_Num
# 0      None        0
# 1      None        1

# %% [markdown]
# # Translating 'ulasan' into English using Google Gemini API
# **Checkpoint 1**
# *   JSON saved in tes_translate

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Used to securely store your API key
from google.colab import userdata

# %%
genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
safety_settings = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_NONE"
    },
]

# %%
# Create Gemini instance using 'gemini-1.0-pro-latest' model
model = genai.GenerativeModel(model_name='gemini-1.0-pro-latest',
                              safety_settings=safety_settings)

# %%
import time
import json

file_num = 0
batch = 10

for i in range(0, len(df), batch):
  # Get 10 rows of 'ulasan'
  df_batch = df[['Row_Num', 'ulasan', 'translate']].iloc[i:i+batch]
  # Convert to JSON
  json_data = df_batch[['Row_Num', 'ulasan','translate']].to_json(orient='records')

  prompt = f"""
  You are an expert linguist, who is good at translating sentences from Indonesian to English.
  Help me translate sentences provided between three backticks.
  Please translate with good grammar.
  Please do not translate word by word.
  In your output, only return the JSON code as output - which is provided between three backticks.
  If there are a quotation mark or anything symbol may cause error in the JSON code in a sentence, please remove it from the output JSON.
  Your task is to update translate labels under 'translate' in the JSON code.
  Error handling instruction: In case a sentence violates API policy, please assign it as Translation Error.
  Don't make any changes to the JSON code format, please.

  ```
  {json_data}
  ```
  """

  # Generate result
  response = model.generate_content(prompt)

  json_result = response.text.strip("`")

  try:
    data = json.loads(json_result)
    print(data)
    # Save result JSON
    file_path = f'/content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/{file_num}_df_{i}_{i+batch}.json'
    json_string = json.dumps(data)

    with open(file_path, 'w') as file:
      file.write(json_string)

    print("JSON data saved to", file_path)
    print("------------------------------------------------------------------------------------")

    file_num += 1
    time.sleep(10)
  except:
    print("Passed: ", file_num)
    print("------------------------------------------------------------------------------------")

    file_num += 1
    pass
# Out:
# [{'Row_Num': 0, 'ulasan': "during ramadan and Eid, the services should have been faster. one cashier was closed, and the other customers squatted since they had to wait for over 20 minutes. Please improve the services. It's not because there were many customers, but the input process was slow. Thank you.", 'translate': 'during Ramazan and Eid, the services should have been faster one cashier was closed, and the other customers squatted since they had to wait for over 20 minutes Please improve the services in other branches It is not because there were many customers, but the input process was slow Thank you'}, {'Row_Num': 1, 'ulasan': "I have been a regular customer here. I'm disappointed with the service by the female employee ES since the bread cashier was closed. My wife had to queue again at the self-service cashier. The point is when the customer complained, the staff got upset, not smiling, being rude, and not saying sorry. They should be trained on how to respond to complaints properly, not arguing with a loud voice or being angry.", 'translate': 'I have been a regular customer here I am disappointed with the service by the female employee ES since the bread cashier was closed My wife had to queue again at the self service cashier The point is when the customer complained, the staff got upset, not smiling, being rude, and not saying sorry They should be trained on how to respond to complaints properly, not arguing with a loud voice or being angry.'}, {'Row_Num': 2, 'ulasan': "the security guard named Lukman and Namnung had bad attitudes. When I asked them properly, they answered me rudely and chatted with the sales promotor girl in the tissue aisle instead of taking care of the thief and the number of missing items. I intended to tell them because there was a suspicious customer, while the store was very crowded. If the security guards don't care, why should I bother? A big store like this should have a qualified security system, focusing on syndicate losses, not just security guards who only focus on managing sales promotor girls. I'm surprised.", 'translate': "the security guard named Lukman and Namnung had bad attitudes When I asked them properly, they answered me rudely and chatted with the sales promotor girl in the tissue aisle instead of taking care of the thief and the number of missing items I intended to tell them because there was a suspicious customer, while the store was very crowded If the security guards don't care, why should I bother? A big store like this should have a qualified security system, focusing on syndicate losses, not just security guards who only focus on managing sales promotor girls I am surprised"}, {'Row_Num': 3, 'ulasan': "please add a parking area for cars. I was surprised. I paid for parking inside Mirota, and I was asked to pay again outside. What does it mean? I'm discouraged to visit Mirota solo branch again.", 'translate': 'please add a parking area for cars I was surprised I paid for parking inside Mirota, and I was asked to pay again outside What does it mean? I am discouraged to visit Mirota solo branch again'}, {'
ai dan diikuti seperti maling semoga ada evaluasi untuk lebih baik kedepannya terima kasih', 'translate': "I have been a very long subscriber to shopping at Mirota Babarsari, so far I have never experienced uncomfortable things, but tonight I was very, very, very uncomfortable with a security guard who always suddenly appeared near me. Starting from the beginning of my shopping in the detergent section, he appeared in the seasoning section, he appeared again when I bought eggs and appeared near me when I was trying to remember what else I needed to buy. Even while I was paying at the cashier he suddenly appeared near me again and again and again. I apologize, during my shopping at Mirota Kampus Babarsari for more than 10 years, this is the first time I have experienced something like this. I feel very uncomfortable if my appearance in a jacket and hat violates the rules or is suspicious, I apologize but I have a reason because I just recovered from ISPA and the flu at that time. It would be better to reprimand me first so that we can understand each other's reasons for wearing a jacket and a hat, rather than me being spied on and followed like a thief. I hope there will be an evaluation for the better in the future, thank you"}, {'Row_Num': 24, 'ulasan': 'pelayan kurang baik kemaren pas kesana saya tanya ada gula pasir ga mas dijawabnya kosong dgn muka cuek bgt ehh pas keliling2 ga sengaja liat gula pasir masih satu selfing penuh mohon yaa sop nya diperbaiki tambahin 5s nya', 'translate': 'The service was not good, yesterday when I went there, I asked if there was any granulated sugar, he answered no with a very indifferent face. Oops, ...
# JSON data saved to /content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/2_df_20_30.json
# ------------------------------------------------------------------------------------
# [{'Row_Num': 30, 'ulasan': 'antrian lama kasirnya sangat lambat', 'translate': 'The queue is slow, the cashier is very slow'}, {'Row_Num': 31, 'ulasan': 'harga di label 13k setelah dikasir katanya salah nempel terus katanya yang bener 33k sangat2 tidak profesional', 'translate': 'Price on label 13k after the cashier said it was wrongly attached, and she said the correct price is 33k, very unprofessional'}, {'Row_Num': 32, 'ulasan': 'tolong kasirnya lemot bgt kak sumpah aseli', 'translate': 'Please, the cashier is very slow, really'}, {'Row_Num': 33, 'ulasan': 'kasir kurang teliti saya membeli barang seharga 5000 tertulis 24 000an', 'translate': 'The cashier is not careful, I bought an item priced at 5000 but they wrote 24,000'}, {'Row_Num': 34, 'ulasan': 'mba mba kasir kaya anj kalo mau kerja yg benar songong kali kau cuih', 'translate': "The cashier has an attitude, if you want to work properly, you're so arrogant"}, {'Row_Num': 35, 'ulasan': 'antrian lama 45 menit saya berdiri', 'translate': 'The queue is long, I was standing for 45 minutes'}, {'Row_Num': 36, 'ulasan': 'pusat belanja paling lengkap segala kebutuhan rumahtangga', 'translate': 'The most complete shopping center for your home needs'}, {'Row_Num': 37, 'ulasan': 'hati2 dan dicek lagi kelengkapan produk untuk pembelian alat yg di dalam dus', 'translate': 'Be careful and double check that the product is complete when buying an item that comes in a box'}, {'Row_Num': 38, 'ulasan': 'harga kok tiba tiba naik yaaa', 'translate': 'Why did the price suddenly increase'}, {'Row_Num': 39, 'ulasan': 'pelayanan untuk drive sangat tidak memuaskan harap di benahi', 'translate': 'The service at drive thru is very disappointing, please fix it'}]
# JSON data saved to /content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/3_df_30_40.json
# ------------------------------------------------------------------------------------
# [{'Row_Num': 40, 'ulasan': 'pelayanan kasir lama benget', 'translate': 'Cashier service is so slow'}, {'Row_Num': 41, 'ulasan': 'tempat belannja dengan harga murah tapi kualitas bagus', 'translate': 'Shopping place with cheap prices but good quality'}, {'Row_Num': 42, 'ulasan': 'jam buka berubah2 menyulitkan pengunjung', 'translate': 'Opening hours change that make it difficult for visitors'}, {'Row_Num': 43, 'ulasan': 'masih jualan miras ternyata', 'translate': 'Still selling liquor'}, {'Row_Num': 44, 'ulasan': 'lama banget sumpah ngantrinya', 'translate': 'Damn, the queue is so long'}, {'Row_Num': 45, 'ulasan': 'pelayannya songong', 'translate': 'The service is arrogant'}, {'Row_Num': 46, 'ulasan': 'saya dak suka pelayanan mirota babarsari', 'translate': 'I do not like the service of Mirota Babarsari'}, {'Row_Num': 47, 'ulasan': 'jl solo km 8 dewan', 'translate': 'Jl Solo km 8, Dewan'}, {'Row_Num': 48, 'ulasan': 'sangat menakjubkan', 'translate': 'Very amazing'}, {'Row_Num': 49, 'ulasan': 'pelayanan sangat lambaat', 'translate': 'Very slow service'}]
# JSON data saved to /content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/4_df_40_50.json
# ------------------------------------------------------------------------------------
# [{'Row_Num': 50, 'ulasan': 'tempat belanja mahasiswa', 'translate': "students' shopping place"}, {'Row_Num': 51, 'ulasan': 'pelayanan tidak memuaskan', 'translate': 'the service was not satisfying'}, {'Row_Num': 52, 'ulasan': 'tidak ramah', 'translate': 'unfriendly'}, {'Row_Num': 53, 'ulasan': 'pelayanan jelek', 'translate': 'bad service'}, {'Row_Num': 54, 'ulasan': 'bagus', 'translate': 'good'}, {'Row_Num': 56, 'ulasan': 'bebas diterjemahkan oleh google lihat versi asli inggris', 'translate': 'free to translate by google see the original English version'}, {'Row_Num': 148, 'ulasan': 'harga yg di tempel sama bayar ke kasir banyak gak cocok coba di cek lagi produk yogurt yoseo kalo gak salah harga 12rb apa ya di diskon jadin7xxrb an pas bayar bukan diskon dan masih banyak lg yg saya beli dan bayar gak sesuai harga yg di tempel di rak coba di cek lagi di update haraganya mau komplain kalo lagi rame yg antri bayar takutnya malah bikin lama yg antri belanja tgl 3 des 2023 jam 17 00wib', 'translate': 'the price displayed on the stickers is not match to the one charged by the cashier. Please check again. especially the price of the yogurt Yoseo. If I remember it correctly, it is 12rb or something discounted to 7xxrb however, it was not discounted at the cashier and there were other items that had the same problem. Please recheck the price and update it. I wanted to complain but at that time there were so many customers. I am afraid that I might end up taking more time that other customers. The cased happened on 3 December 2023 at 17.00 WIB'}, {'Row_Num': 149, 'ulasan': 'tgl 14 feb pas pemilu di google bisnis tertera buka saat itu jam 9 pagi setelah sampai lokasi ternyata tutup tolonglah buat admin mirota untuk hal seperti ini mohon untuk lebih diperhatikan', 'translate': 'on 14 February during the election day, in the Google Business it was stated that Mirota opens at 9:00 am.  However, when I arrived at the location it was closed. I hope the admin of
row_Num': 168, 'ulasan': 'buatin parkir buat mobil dong biar tdk mempersempit jalur umum bikin macet', 'translate': "Please make a parking lot for cars so it doesn't narrow the public road and cause traffic jams"}, {'Row_Num': 169, 'ulasan': 'kasir di tempat alat tulis kantor kurang senyum bila di sapa', 'translate': "The cashier at the stationery shop doesn't smile enough when greeted"}, {'Row_Num': 170, 'ulasan': 'lumayan lengkap walau tak selengkap yg di jalan simanjuntak', 'translate': "It's quite complete, although not as complete as the one on Jalan Simanjuntak"}, {'Row_Num': 171, 'ulasan': 'komplit harga bersahabat utk kalangan pelajar', 'translate': 'Complete with affordable prices for students'}]
# JSON data saved to /content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/7_df_70_80.json
# ------------------------------------------------------------------------------------
# [{'Row_Num': 172, 'ulasan': 'barangnya tidak selengkap mirota kampus jalan simanjuntak', 'translate': 'Items not as complete as Mirota Campus at Jalan Simanjuntak'}, {'Row_Num': 173, 'ulasan': 'tukang parkir tidak ramah', 'translate': 'Unfriendly parking attendant'}, {'Row_Num': 174, 'ulasan': 'lengkap harga lebih rumah', 'translate': 'Complete, more expensive than home'}, {'Row_Num': 175, 'ulasan': 'penataan dagangan kurang siip', 'translate': 'Messy merchandise arrangement'}, {'Row_Num': 176, 'ulasan': 'sempit dan salesnya gak welcome', 'translate': 'Narrow and the sales are not welcoming'}, {'Row_Num': 177, 'ulasan': 'buahnya tidak segar', 'translate': 'Fruits are not fresh'}, {'Row_Num': 178, 'ulasan': 'susah parkir mobil', 'translate': 'Difficult to park cars'}, {'Row_Num': 179, 'ulasan': 'parkirnya kurang', 'translate': 'Parking is insufficient'}, {'Row_Num': 180, 'ulasan': 'lumayan murah', 'translate': 'Quite affordable'}, {'Row_Num': 181, 'ulasan': 'sempit', 'translate': 'Narrow'}]
# JSON data saved to /content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/8_df_80_90.json
# ------------------------------------------------------------------------------------
# [{'Row_Num': 182, 'ulasan': 'tukangparkir rese', 'translate': 'Annoying parking attendants'}, {'Row_Num': 183, 'ulasan': 'sempit', 'translate': 'Narrow'}, {'Row_Num': 184, 'ulasan': 'parkir mobil itu gila orang orang turun di tengah jalan terlalu berbahaya diterjemahkan oleh google lihat versi asli inggris', 'translate': 'Car parking is crazy, people getting out in the middle of the road, very dangerous, translated by google see original english text'}, {'Row_Num': 185, 'ulasan': 'keamanan tidak ramah mohon kepada perusahaan mereka harus berlatih lebih baik lagi diterjemahkan oleh google lihat versi asli inggris', 'translate': 'The security is not friendly, I ask their company to train them better, translated by google see original english text'}, {'Row_Num': 186, 'ulasan': 'penempatan barangnya sangat tidak masuk akal dan tidak rapi sangat membosankan dan tidak menarik diterjemahkan oleh google lihat versi asli inggris', 'translate': 'The placement of the goods is very unreasonable and messy, very boring and unattractive, translated by google see original english text'}, {'Row_Num': 187, 'ulasan': 'tidak mempunyai tempat parkir yang luas diterjemahkan oleh google lihat versi asli inggris
fresh products. The place is small but it's quite cheap compared to Jakarta."}, {'Row_Num': 274, 'ulasan': 'tempat belanja paling lengkap dan favorit hanya saja ada beberapa karyawan yang berdiri bersandar depan rak ngalangin barang barang hingga segan buat ngambil barangnya dan sedikit gak nyaman karena ditatapin terus', 'translate': "The most complete and favorite shopping place. However, there are some employees who stand and lean in front of the shelves, blocking the items, so it's awkward to take the items. Also, it's a bit uncomfortable because they keep staring at me."}, {'Row_Num': 275, 'ulasan': 'cocok untuk tempat belanja saya tempat tidak terlalu besar dn juga lengkap', 'translate': "It's suitable as my shopping place. The place isn't too large and complete."}, {'Row_Num': 276, 'ulasan': 'harga2 barang lebih murah daripada tempat lain tapi suasana terlalu crowded lorong lorong terlalu sempit dan antrean kasir terlalu panjang', 'translate': "The prices of goods are cheaper than other places. However, it's too crowded, the aisles are too narrow, and the line at the cashier is too long."}, {'Row_Num': 277, 'ulasan': 'setiap bulan belanja disini untuk kebutuhan bulanan kasir ramah dan sangat membantu hanya saja terkadang ada beberapa spg yang santai mengobrol dan beberapa kali menemukan produk deterjen yang sudah exp masih dijual semoga kedepannya lebih teliti lagi untuk cek exp suatu barang', 'translate': 'I shop here every month for monthly needs. The cashiers are friendly and very helpful. However, sometimes there are several SPGs who chat casually, and several times I found that expired detergent products were still being sold. Hopefully in the future, checking the expiry of a product will be done more carefully.'}, {'Row_Num': 278,  ...
# JSON data saved to /content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/11_df_110_120.json
# ------------------------------------------------------------------------------------
# [{'Row_Num': 279, 'ulasan': 'bisa ditegur tukang parkirnya agar lebih kerja bukan cuma nungguin kertas dan tidak membantu motor yg kesusahan sering juga perbedaan harga di struk dengan di rak biasa munkin bisa diperbaiki lagi', 'translate': 'The parking attendant should be reprimanded so that he will work more and not just wait for a piece of paper and not help motorcycles in trouble. There are often differences in price between the receipt and the ordinary shelves. Maybe this could be fixed too.'}, {'Row_Num': 280, 'ulasan': 'jelek kasir banyak yang lemot sehingga antri mengular dan kasir beberapa kali salah menjumlah nota dikomplain juga kurang memuaskan solusinya tempatnya sumpek juga yg paling utama benahi dulu karyawan2nya terutama kasir barang sudah lewat masa promo over kuota tapi stempel promo di etalase seringkali ga dicabut semoga bisa dibenahi dan lebih baik kedepannya kurang lengkap juga barang2nya maaf review jujur', 'translate': 'Bad cashier. Many of them are slow that cause a long queue. And the cashier has made mistake in counting the notes several times. If it is complained, the solution is not satisfying. Besides, the place is stuffy. The most important thing is to fix the employees, especially the cashiers. There are items already past the promo period and over the quota, but the promo stamp on the display is often not removed. Hopefully this could be fixed and improved. The items are also not complete. Sorry for my honest review.'}, {'Row_Num': 281, 'ulasan': 'masukan untuk mirota pelanggan driver grab mart tolong diberi kursi untuk tempat duduk agar tidak terkesan ting kleset kalau memang driver tidak boleh masuk tolong dibuat kasa sendiri yang langsung terhubung di luar proses penerimaan barang jangan kasa di dalam driver di luar agar bisa ada komunikasi lanjut bilamana diperlukan
oknya', 'translate': "The price is cheap, the staffs are friendly, and it's closer to home. Awesome!"}, {'Row_Num': 4728, 'ulasan': 'parkir luas muat 4 mobil keperluan sehari2 komplit mantap', 'translate': 'Spacious parking for 4 cars, complete daily necessities, awesome'}, {'Row_Num': 4729, 'ulasan': 'barang yang saya cari ada di sini tempatnya bersih walaupun di luar tidak ada tempat duduk', 'translate': 'The items I was looking for were available here, the place is clean, even though there is no seating area outside'}, {'Row_Num': 4730, 'ulasan': 'karyawannya ramah ramah tempatnya nyaman harga murah manna kampus mini diro ok', 'translate': 'The staffs are friendly, the place is comfortable, the price is cheap, Manna Campus Mini Dito is okay'}, {'Row_Num': 4731, 'ulasan': 'harga terjangkau komplit dekat rumah', 'translate': 'Affordable price, complete items, close to home'}]
# JSON data saved to /content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/282_df_2820_2830.json
# ------------------------------------------------------------------------------------
# [{'Row_Num': 4732, 'ulasan': 'bersih rapi pelayanannya ramah suka banget kesini', 'translate': 'clean, tidy, friendly service, I really like it here'}, {'Row_Num': 4733, 'ulasan': 'semakin dekat dengan harga yang murah pelayanan juga baik', 'translate': 'closer to cheap prices, good service'}, {'Row_Num': 4734, 'ulasan': 'lebih murah dari jaringan toko sebelah', 'translate': 'cheaper than the next store chain'}, {'Row_Num': 4735, 'ulasan': 'harganya sama murahnya dengan mk yang lain dan lebih dekat', 'translate': 'the price is as cheap as other MKs and closer'}, {'Row_Num': 4736, 'ulasan': 'murah dan terpercaya rotinya juga enak2', 'translate': 'cheap and trusted, the breads are also delicious'}, {'Row_Num': 4737, 'ulasan': 'pelayannya ramah harganya jg murah', 'translate': 'the service is friendly, the prices are also cheap'}, {'Row_Num': 4738, 'ulasan': 'murah banyak promo ramah lagi', 'translate': 'cheap, many promos, friendly too'}, {'Row_Num': 4739, 'ulasan': 'suasananya nyaman lengkap luar biaaa', 'translate': 'the atmosphere is comfortable, very complete'}, {'Row_Num': 4740, 'ulasan': 'pelayanannya ramah dan memuaskan', 'translate': 'the service is friendly and satisfying'}, {'Row_Num': 4741, 'ulasan': 'harganya murah dan lebih dekat', 'translate': 'the price is cheap and closer'}]
# JSON data saved to /content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/283_df_2830_2840.json
# ------------------------------------------------------------------------------------
# [{'Row_Num': 4742, 'ulasan': 'tempat parkir cukup luas', 'translate': 'The parking lot is wide enough'}, {'Row_Num': 4743, 'ulasan': 'harganya murah murah', 'translate': 'The price is cheap'}, {'Row_Num': 4744, 'ulasan': 'rumah belanja terpercaya', 'translate': 'Trusted shopping place'}, {'Row_Num': 4745, 'ulasan': 'murah ramah', 'translate': 'Cheap and friendly'}, {'Row_Num': 4746, 'ulasan': 'komplit', 'translate': 'Complete'}, {'Row_Num': 4747, 'ulasan': 'manna kampus mini diro merupakan minimarket yang menjual makanan ringan minuman dan produk lainnya merupakan bagian dari kelompok usaha manna kampus letaknya di jl bantul no 8 diro pendowoharjo kec sewon saya mengunjungi tempat ini minggu lalu dan saya menikmati produk yang mereka tawarkan stafnya ramah dan membantu dan tokonya bersih dan terorganisir dengan baik harganya masuk akal dan kompetitif saya akan merekomendasikan tempat ini kepada siapa saja yang perlu membeli beberapa kebutuhan pokok ini adalah minimarket yang nyaman dan dapat diandalkan diterjemahkan oleh google lihat versi asli inggris', 'translate': 'Manna Kampus Mini Dira is a minimarket that sells snacks, drinks, and other products, and is part of the Manna Kampus business group. It is located on Jl. Bantul, No.8, Dira, Pendowoharjo, Sewon District. I visited this place last week and I enjoyed the products they offered. The staff is friendly and helpful, and the store is clean and well-organized. The prices are reasonable and competitive. I would recommend this place to anyone who needs to buy some basic necessities. It is a convenient and reliable minimarket.'}, {'Row_Num': 4748, 'ulasan': 'akhirnya tak perlu jauh jauh ke manna kampus jl godean semakin dekat dengan rumah saya masih bisa mengumpulkan poin semoga bisa mendapatkan mobil ayla itu kenapa aku yang mengantar andin diterjemahkan oleh google lihat versi asli jawa', 'translate': 'No need to rush to Manna Kampus Jl. Godean is getting closer to my house I can still collect points I hope to get the car'}, {'Row_Num': 4749, 'ulasan': 'pelayanannya sungguh memuaskan harganya masuk akal barangnya lengkap diterjemahkan oleh google lihat versi asli jawa', 'translate': 'The service is really satisfying, the price is reasonable, the goods are complete'}, {'Row_Num': 4750, 'ulasan': 'cerdas kecil tapi lengkap diterjemahkan oleh google lihat versi asli inggris', 'translate': 'Smart, small but complete'}]
# JSON data saved to /content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate/284_df_2840_2850.json
# ------------------------------------------------------------------------------------

# %% [markdown]
# # Check failed translation batch

# %%
# import os

# List all files in the current directory
files = os.listdir('/content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate')

# Extract numbers from filenames and convert them to integers
numbers = [int(filename.split('_')[0]) for filename in files]

# Sort the numbers
numbers.sort()

# Check for skipped numbers
skipped_numbers = []
for i in range(len(numbers) - 1):
    if numbers[i+1] - numbers[i] != 1:
        skipped_numbers.append(numbers[i] + 1)

if skipped_numbers:
    print("Skipped batch detected:", skipped_numbers)
else:
    print("No skipped batch detected.")
# Out:
# Skipped batch detected: [13, 38, 41, 50, 55, 80, 89, 92, 116, 165, 174, 200, 227, 242, 250, 262, 265, 281]

# %% [markdown]
# # Append translate to dataframe

# %%
json_dir = '/content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/tes_translate'

# %%
for filename in os.listdir(json_dir):
    if filename.endswith('.json'):
        filepath = os.path.join(json_dir, filename)
        with open(filepath, 'r') as file:
            # Load JSON data
            json_data = json.load(file)
            for x in json_data:
              df.at[x['Row_Num'], 'translate'] = x['translate']

# %% [markdown]
# **Checkpoint 2**
# *   Dataframe saved as 2024-4-23_translatedUlasanGemini.csv

# %%
# Save dataframe with translation as csv
df.to_csv('/content/drive/MyDrive/Colab Notebooks/2024-3-31_HRA/2024-4-23_translatedUlasanGemini.csv', index=False)
